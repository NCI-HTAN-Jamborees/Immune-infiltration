# %% [markdown]
# # This notebook summarize the matched single cell and 10x visium file names in the WUSTL PDAC Cohort

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Load file name and viable patient metadata table

# %% [markdown]
# RNA sample file names

# %%
viable_sample_RNA = pd.read_csv("../output/tables/ViableSamples_WUSTL_Filenames.csv", header = 0, index_col = 0 )

# %%
viable_sample_RNA.iloc[0, 1]
# Out:
# 'sn_RNAseq_level_3/HT264P1-S1H2Fc2A2N1Z1_1Bmn1-barcodes.tsv.gz'

# %%
viable_sample_RNA.head()
# Out:
#   HTAN.Participant.ID                                           Filename  \
# 1            HTA12_27  sn_RNAseq_level_3/HT264P1-S1H2Fc2A2N1Z1_1Bmn1-...
# 2            HTA12_27  sn_RNAseq_level_3/HT264P1-S1H2Fc2A2N1Z1_1Bmn1-...
# 3            HTA12_27  sn_RNAseq_level_3/HT264P1-S1H2Fc2A2N1Z1_1Bmn1-...
# 4            HTA12_22  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-barc...
# 5            HTA12_22  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-feat...
#
#   Biospecimen      Assay
# 1  HTA12_27_4  scRNA-seq
# 2  HTA12_27_4  scRNA-seq
# 3  HTA12_27_4  scRNA-seq
# 4  HTA12_22_3  scRNA-seq
# 5  HTA12_22_3  scRNA-seq

# %%
all_sample_RNA = pd.read_csv("../input/WUSTL_scRNA_all_files.tsv", header = 0, index_col = None , delimiter = '\t')
all_sample_RNA.head(2)
# Out:
#                                             Filename  Atlas Name Biospecimen  \
# 0  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-barc...  HTAN WUSTL  HTA12_22_3
# 1  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-feat...  HTAN WUSTL  HTA12_22_3
#
#        Assay    Level         Organ                             Diagnosis  \
# 0  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
#   Data Access File Format HTAN Parent Data File ID  ...  \
# 0     Synapse        gzip            HTA12_22_2001  ...
# 1     Synapse        gzip            HTA12_22_2001  ...
#
#                                        Workflow Link      Workflow Version  \
# 0  https://support.10xgenomics.com/single-cell-mu...  cellranger-arc-1.0.1
# 1  https://support.10xgenomics.com/single-cell-mu...  cellranger-arc-1.0.1
#
#     Synapse Id  Atlasid   Data File ID  Parent Data File ID  \
# ...

# %%
all_sample_RNA.shape
# Out:
# (252, 29)

# %%
all_sample_RNA['HTAN.Participant.ID'] = ['_'.join( b.split('_')[0:2] ) for b in all_sample_RNA['Biospecimen']]

# %%
all_sample_RNA['HTAN.Participant.ID'].unique()
# Out:
# array(['HTA12_22', 'HTA12_23', 'HTA12_24', 'HTA12_25', 'HTA12_26',
#        'HTA12_27', 'HTA12_28', 'HTA12_29', 'HTA12_30', 'HTA12_31',
#        'HTA12_32', 'HTA12_1', 'HTA12_2', 'HTA12_3', 'HTA12_4', 'HTA12_5',
#        'HTA12_6', 'HTA12_7', 'HTA12_8', 'HTA12_9', 'HTA12_10', 'HTA12_11',
#        'HTA12_12', 'HTA12_13', 'HTA12_14', 'HTA12_15', 'HTA12_16',
#        'HTA12_17', 'HTA12_18', 'HTA12_19', 'HTA12_20', 'HTA12_21'],
#       dtype=object)

# %%
all_sample_RNA2 = all_sample_RNA[np.isin(all_sample_RNA['HTAN.Participant.ID'], sample_visium['HTAN.Participant.ID'] ) ]

# %%
all_sample_RNA2.shape
# Out:
# (30, 30)

# %%
all_sample_RNA2['HTAN.Participant.ID'].unique()
# Out:
# array(['HTA12_22', 'HTA12_23', 'HTA12_24', 'HTA12_25', 'HTA12_26',
#        'HTA12_27', 'HTA12_28', 'HTA12_29', 'HTA12_30', 'HTA12_31'],
#       dtype=object)

# %% [markdown]
# Visium sample filenames

# %%
sample_visium = pd.read_csv("../input/WUSTL_visium_file_names.tsv", header = 0, index_col = None , delimiter = '\t')

# %%
sample_visium.head()
# Out:
#                                             Filename  Atlas Name Biospecimen  \
# 0  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-bar...  HTAN WUSTL  HTA12_22_4
# 1  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-fea...  HTAN WUSTL  HTA12_22_4
# 2  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-mat...  HTAN WUSTL  HTA12_22_4
# 3  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-tis...  HTAN WUSTL  HTA12_22_4
# 4  visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
#
#         Assay    Level         Organ                             Diagnosis  \
# 0  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 2  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 3  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 4  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
# ...

# %%
sample_visium['HTAN.Participant.ID'] = ['_'.join( b.split('_')[0:2] ) for b in sample_visium['Biospecimen']]

# %%
sample_visium['HTAN.Participant.ID'].unique()
# Out:
# array(['HTA12_22', 'HTA12_23', 'HTA12_24', 'HTA12_25', 'HTA12_26',
#        'HTA12_27', 'HTA12_28', 'HTA12_29', 'HTA12_30', 'HTA12_31',
#        'HTA12_33', 'HTA12_34'], dtype=object)

# %% [markdown]
# matched patient sample IDs

# %%
#matched_patients = pd.read_csv("../output/tables/ViableSamples_WUSTL.csv", header = 0, index_col=0)

# %%
#matched_patients.head()
# Out:
#   HTAN.Participant.ID Atlas.Name.x  Age.at.Diagnosis..years..x  \
# 1            HTA12_27   HTAN WUSTL                          77
# 2            HTA12_22   HTAN WUSTL                          61
# 3            HTA12_23   HTAN WUSTL                          63
# 4            HTA12_24   HTAN WUSTL                          60
# 5            HTA12_25   HTAN WUSTL                          66
#
#    Year.of.Diagnosis.x                               Primary.Diagnosis.x  \
# 1                 2020  Mixed adenocarcinoma and squamous cell carcinoma
# 2                 2020              Adenocarcinoma pancreatobiliary type
# 3                 2020              Adenocarcinoma pancreatobiliary type
# 4                 2020              Adenocarcinoma pancreatobiliary type
# 5                 2016              Adenocarcinoma pancreatobiliary type
#
#   Site.of.Resection.or.Biopsy.x Tissue.or.Organ.of.Origin.x  Morphology.x  \
# ...

# %%
#matched_patients.shape
# Out:
# (10, 229)

# %%
#matched_patient_ids = matched_patients['HTAN.Participant.ID']

# %%
matched_patient_ids = list( set(sample_visium['HTAN.Participant.ID']).intersection( set(all_sample_RNA2['HTAN.Participant.ID']) ) )

# %%
len( matched_patient_ids )
# Out:
# 10

# %%
matched_patient_ids
# Out:
# ['HTA12_26',
#  'HTA12_22',
#  'HTA12_25',
#  'HTA12_27',
#  'HTA12_31',
#  'HTA12_23',
#  'HTA12_29',
#  'HTA12_28',
#  'HTA12_30',
#  'HTA12_24']

# %%
viable_sample_visium = sample_visium[np.isin(sample_visium['HTAN.Participant.ID'] , matched_patient_ids)]

# %%
viable_sample_visium.shape
# Out:
# (60, 34)

# %%
viable_sample_visium
# Out:
#                                              Filename  Atlas Name Biospecimen  \
# 0   visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-bar...  HTAN WUSTL  HTA12_22_4
# 1   visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-fea...  HTAN WUSTL  HTA12_22_4
# 2   visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-mat...  HTAN WUSTL  HTA12_22_4
# 3   visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-tis...  HTAN WUSTL  HTA12_22_4
# 4   visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
# 5   visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
# 6   visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
# 7   visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
# 8     visium_level_3_pdac/HT232P1H1A2-barcodes.tsv.gz  HTAN WUSTL  HTA12_24_5
# 9     visium_level_3_pdac/HT232P1H1A2-features.tsv.gz  HTAN WUSTL  HTA12_24_5
# 10      visium_level_3_pdac/HT232P1H1A2-matrix.mtx.gz  HTAN WUSTL  HTA12_24_5
# ...

# %%
viable_sample_RNA2 = all_sample_RNA[np.isin(all_sample_RNA['HTAN.Participant.ID'] , matched_patient_ids)]

# %%
viable_sample_RNA2.shape
# Out:
# (30, 30)

# %%
viable_sample_RNA2
# Out:
#                                              Filename  Atlas Name Biospecimen  \
# 0   sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-barc...  HTAN WUSTL  HTA12_22_3
# 1   sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-feat...  HTAN WUSTL  HTA12_22_3
# 2   sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-matr...  HTAN WUSTL  HTA12_22_3
# 3   sn_RNAseq_level_3/HT231P1-S1H3Fc2A2N1Z1_1Bmn1_...  HTAN WUSTL  HTA12_23_2
# 4   sn_RNAseq_level_3/HT231P1-S1H3Fc2A2N1Z1_1Bmn1_...  HTAN WUSTL  HTA12_23_2
# 5   sn_RNAseq_level_3/HT231P1-S1H3Fc2A2N1Z1_1Bmn1_...  HTAN WUSTL  HTA12_23_2
# 6   sn_RNAseq_level_3/HT232P1-S1H1Fc2A2_1N1Bmn1_1-...  HTAN WUSTL  HTA12_24_4
# 7   sn_RNAseq_level_3/HT232P1-S1H1Fc2A2_1N1Bmn1_1-...  HTAN WUSTL  HTA12_24_4
# 8   sn_RNAseq_level_3/HT232P1-S1H1Fc2A2_1N1Bmn1_1-...  HTAN WUSTL  HTA12_24_4
# 9   sn_RNAseq_level_3/HT242P1-S1H1Fc2A2N1Z1_1Bmn1-...  HTAN WUSTL  HTA12_25_3
# 10  sn_RNAseq_level_3/HT242P1-S1H1Fc2A2N1Z1_1Bmn1-...  HTAN WUSTL  HTA12_25_3
# ...

# %%
len(matched_patient_ids)
# Out:
# 10

# %%
len( viable_sample_RNA2['HTAN.Participant.ID'].unique() )
# Out:
# 10

# %%
len( viable_sample_visium['HTAN.Participant.ID'].unique() )
# Out:
# 10

# %% [markdown]
# ## extract the file names from the viable file table

# %%
viable_sample_RNA2.head()
# Out:
#                                             Filename  Atlas Name Biospecimen  \
# 0  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-barc...  HTAN WUSTL  HTA12_22_3
# 1  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-feat...  HTAN WUSTL  HTA12_22_3
# 2  sn_RNAseq_level_3/HT224P1-S1Fc2A2N1Bmn1_1-matr...  HTAN WUSTL  HTA12_22_3
# 3  sn_RNAseq_level_3/HT231P1-S1H3Fc2A2N1Z1_1Bmn1_...  HTAN WUSTL  HTA12_23_2
# 4  sn_RNAseq_level_3/HT231P1-S1H3Fc2A2N1Z1_1Bmn1_...  HTAN WUSTL  HTA12_23_2
#
#        Assay    Level         Organ                             Diagnosis  \
# 0  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 2  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 3  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 4  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
# ...

# %%
viable_sample_RNA2.iloc[0,1]
# Out:
# 'sn_RNAseq_level_3/HT264P1-S1H2Fc2A2N1Z1_1Bmn1-barcodes.tsv.gz'

# %%
viable_sample_RNA = viable_sample_RNA2

# %%
viable_sample_RNA['pathname'] = viable_sample_RNA['Filename'].copy()
# Out:
# /tmp/ipykernel_1438119/2997523980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   viable_sample_RNA['pathname'] = viable_sample_RNA['Filename'].copy()

# %%
viable_sample_RNA['Filename'] = [ f.split('/')[1] for f in viable_sample_RNA['pathname'] ]
# Out:
# /tmp/ipykernel_1438119/1477994980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   viable_sample_RNA['Filename'] = [ f.split('/')[1] for f in viable_sample_RNA['pathname'] ]

# %%
viable_sample_RNA.head()
# Out:
#                                         Filename  Atlas Name Biospecimen  \
# 0        HT224P1-S1Fc2A2N1Bmn1_1-barcodes.tsv.gz  HTAN WUSTL  HTA12_22_3
# 1        HT224P1-S1Fc2A2N1Bmn1_1-features.tsv.gz  HTAN WUSTL  HTA12_22_3
# 2          HT224P1-S1Fc2A2N1Bmn1_1-matrix.mtx.gz  HTAN WUSTL  HTA12_22_3
# 3  HT231P1-S1H3Fc2A2N1Z1_1Bmn1_1-barcodes.tsv.gz  HTAN WUSTL  HTA12_23_2
# 4  HT231P1-S1H3Fc2A2N1Z1_1Bmn1_1-features.tsv.gz  HTAN WUSTL  HTA12_23_2
#
#        Assay    Level         Organ                             Diagnosis  \
# 0  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 2  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 3  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 4  scRNA-seq  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
#   Data Access File Format HTAN Parent Data File ID  ...   Synapse Id Atlasid  \
# ...

# %%
viable_sample_visium.head()
# Out:
#                                             Filename  Atlas Name Biospecimen  \
# 0  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-bar...  HTAN WUSTL  HTA12_22_4
# 1  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-fea...  HTAN WUSTL  HTA12_22_4
# 2  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-mat...  HTAN WUSTL  HTA12_22_4
# 3  visium_level_3_pdac/HT224P1-S1Fc2U1Z1Bs1-1-tis...  HTAN WUSTL  HTA12_22_4
# 4  visium_level_3_pdac/HT231P1-S1H3Fc2U1Z1Bs1-H3B...  HTAN WUSTL  HTA12_23_3
#
#         Assay    Level         Organ                             Diagnosis  \
# 0  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 2  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 3  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 4  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
# ...

# %%
viable_sample_visium['pathname'] = viable_sample_visium['Filename'].copy()
# Out:
# /tmp/ipykernel_1438119/3621574851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   viable_sample_visium['pathname'] = viable_sample_visium['Filename'].copy()

# %%
viable_sample_visium.loc[:,'Filename'] = [ f.split('/')[1] for f in viable_sample_visium['pathname']]
# Out:
# /home/lucy/anaconda3/envs/qc_pipe/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
viable_sample_visium.head()
# Out:
#                                             Filename  Atlas Name Biospecimen  \
# 0             HT224P1-S1Fc2U1Z1Bs1-1-barcodes.tsv.gz  HTAN WUSTL  HTA12_22_4
# 1             HT224P1-S1Fc2U1Z1Bs1-1-features.tsv.gz  HTAN WUSTL  HTA12_22_4
# 2               HT224P1-S1Fc2U1Z1Bs1-1-matrix.mtx.gz  HTAN WUSTL  HTA12_22_4
# 3   HT224P1-S1Fc2U1Z1Bs1-1-tissue_positions_list.csv  HTAN WUSTL  HTA12_22_4
# 4  HT231P1-S1H3Fc2U1Z1Bs1-H3Bs2-Test-barcodes.tsv.gz  HTAN WUSTL  HTA12_23_3
#
#         Assay    Level         Organ                             Diagnosis  \
# 0  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 1  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 2  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 3  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
# 4  10x Visium  Level 3  Pancreas NOS  Adenocarcinoma pancreatobiliary type
#
# ...

# %% [markdown]
# ## Combined the two assay file names

# %%
viable_sample_visium.columns
# Out:
# Index(['Filename', 'Atlas Name', 'Biospecimen', 'Assay', 'Level', 'Organ',
#        'Diagnosis', 'Data Access', 'File Format', 'HTAN Data File ID',
#        'HTAN Parent Biospecimen ID', 'HTAN Parent Data File ID', 'Run ID',
#        'Visium File Type', 'Workflow Version', 'Workflow Link', 'Capture Area',
#        'Spotsundertissue', 'Mean Readsper Spatial Spot',
#        'Median Number Genesper Spatial Spot', 'Sequencing Saturation',
#        'Proportion Reads Mapped', 'Proportion Reads Mappedto Transcriptome',
#        'Median UMI Countsper Spot', 'Synapse Id', 'Atlasid', 'Data File ID',
#        'Parent Biospecimen ID', 'Parent Data File ID', 'Is Raw Sequencing',
#        'Release Version', 'Metadata', 'View', 'HTAN.Participant.ID',
#        'pathname'],
#       dtype='object')

# %%
viable_sample_visium.iloc[0]
# Out:
# Filename                                              HT224P1-S1Fc2U1Z1Bs1-1-barcodes.tsv.gz
# Atlas Name                                                                        HTAN WUSTL
# Biospecimen                                                                       HTA12_22_4
# Assay                                                                             10x Visium
# Level                                                                                Level 3
# Organ                                                                           Pancreas NOS
# Diagnosis                                               Adenocarcinoma pancreatobiliary type
# Data Access                                                                          Synapse
# File Format                                                                             gzip
# HTAN Data File ID                                                              HTA12_22_3004
# ...

# %%
vis_table = viable_sample_visium[ [ 'HTAN.Participant.ID', 'Filename',  'Biospecimen', 'Assay',] ]

# %%
rna_table = viable_sample_RNA[ ['HTAN.Participant.ID', 'Filename',  'Biospecimen', 'Assay',] ]

# %%
combined = pd.concat([vis_table, rna_table] , axis = 0 )

# %%
combined.sort_values(by = 'HTAN.Participant.ID', inplace= True)

# %%
combined
# Out:
#    HTAN.Participant.ID                                           Filename  \
# 0             HTA12_22             HT224P1-S1Fc2U1Z1Bs1-1-barcodes.tsv.gz
# 1             HTA12_22             HT224P1-S1Fc2U1Z1Bs1-1-features.tsv.gz
# 2             HTA12_22               HT224P1-S1Fc2U1Z1Bs1-1-matrix.mtx.gz
# 3             HTA12_22   HT224P1-S1Fc2U1Z1Bs1-1-tissue_positions_list.csv
# 2             HTA12_22              HT224P1-S1Fc2A2N1Bmn1_1-matrix.mtx.gz
# ..                 ...                                                ...
# 59            HTA12_31  HT306P1-S1H1Fc2U1Z1Bs1-H1Bs2-Test-tissue_posit...
# 56            HTA12_31  HT306P1-S1H1Fc2U1Z1Bs1-H1Bs2-Test-barcodes.tsv.gz
# 57            HTA12_31  HT306P1-S1H1Fc2U1Z1Bs1-H1Bs2-Test-features.tsv.gz
# 28            HTA12_31      HT306P1-S1H1Fc2A2N1Z1_1Bmn1_1-features.tsv.gz
# 29            HTA12_31        HT306P1-S1H1Fc2A2N1Z1_1Bmn1_1-matrix.mtx.gz
#
#    Biospecimen       Assay
# 0   HTA12_22_4  10x Visium
# ...

# %% [markdown]
# ## save result

# %%
combined.to_csv("../output/tables/WUSTL_matched_visium_scRNA_filename.csv", header = True, index = False )
